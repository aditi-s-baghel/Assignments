# %% [markdown]
# # Python OOPs Assignment
#
# ## Topic:
# - Class
# - Object
# - Method/function
# - self Keyword
#
# ## Level: Basic
#
# ### Instructions
# - Solve all questions using Python
# - Use classes and objects only
# - Focus on understanding `self`
# - Write clean and readable code

# %% [markdown]
# # Q1. Create a Student Class
#
# ## Problem Statement
# Create a class named `Student` and create an object of that class.
#
# Print:
# - Student Name
# - Student Age
#
# ## Sample Output
# ```python
# Name: Raj
# Age: 17
# ```

# %%
class Student:
    name = "Raj"
    age = 17

obj = Student()
print(f"Name: {Student.name}")
print(f"Age: {Student.age}")
# Out:
# Name: Raj
# Age: 17

# %% [markdown]
# # Q2. Create a Car Class
#
# ## Problem Statement
# Create a class named `Car`.
#
# Using object, store:
# - Car Name
# - Car Price
#
# Print both values.
#
# ## Sample Output
# ```python
# Car Name: BMW
# Car Price: 5000000
# ```

# %%
class Car:
    name = "BMW"
    price = 5000000

obj = Car()
print(f"Car Name: {Car.name}")
print(f"Car Price: {Car.price}")
# Out:
# Car Name: BMW
# Car Price: 5000000

# %% [markdown]
# # Q3. Use self Keyword
#
# ## Problem Statement
# Create a class named `Employee`.
#
# Create a method using `self` keyword to print:
# - Employee Name
# - Employee Salary
#
# ## Sample Output
# ```python
# Name: Rahul
# Salary: 45000
# ```

# %%
class Employee:
    def functn(self,name,salary):
        self.name = name
        self.salary = salary
        print("Name:",self.name)
        print("Salary:",self.salary)

obj = Employee()
obj.functn("Rahul",45000)
# Out:
# Name: Rahul
# Salary: 45000

# %% [markdown]
# # Q4. Mobile Class
#
# ## Problem Statement
# Create a class named `Mobile`.
#
# Store:
# - Brand Name
# - RAM
#
# Using object, print both values.
#
# ## Sample Output
# ```python
# Brand: Samsung
# RAM: 8GB
# ```

# %%
class Mobile:
    def __init__(self,name,ram):
        self.name = name
        self.ram = ram
    def phone(self):
        print("Brand:",self.name)
        print("RAM:",self.ram)

obj = Mobile("SAmsung","8GB")
obj.phone()
# Out:
# Brand: SAmsung
# RAM: 8GB

# %% [markdown]
# # Q5. Student Details using Method
#
# ## Problem Statement
# Create a class named `Student`.
#
# Create a method `show()` using `self` keyword and print:
# - Name
# - Course
#
# ## Sample Output
# ```python
# Name: Aman
# Course: Python
# ```

# %%
class Student:
    def method(self):
        print("Name: Aman")
        print("Course: Python")

obj = Student()
obj.method()
# Out:
# Name: Aman
# Course: Python

# %% [markdown]
# # Q6. Laptop Class
#
# ## Problem Statement
# Create a class named `Laptop`.
#
# Store:
# - Laptop Brand
# - Processor
#
# Print both details using object.
#
# ## Sample Output
# ```python
# Brand: HP
# Processor: i5
# ```

# %%
class Laptop:
    def details(self,brand,processor):
        self.brand = brand
        self.processor = processor
        print("Brand:",self.brand)
        print("Processor:",self.processor)

obj = Laptop()
obj.details("HP","i5")
# Out:
# Brand: HP
# Processor: i5

# %% [markdown]
# # Q7. Book Class
#
# ## Problem Statement
# Create a class named `Book`.
#
# Create attributes:
# - Book Name
# - Book Price
#
# Print details using object.
#
# ## Sample Output
# ```python
# Book Name: Python Basics
# Book Price: 499
# ```

# %%
class Book:
    name = "Python Basics"
    price = 499

obj = Book()
print("Book Name: ",obj.name)
print("Book Price: ",obj.price)
# Out:
# Book Name:  Python Basics
# Book Price:  499

# %% [markdown]
# # Q8. Teacher Class using self
#
# ## Problem Statement
# Create a class named `Teacher`.
#
# Create method using `self` keyword to print:
# - Teacher Name
# - Subject
#
# ## Sample Output
# ```python
# Teacher Name: Neha
# Subject: Maths
# ```

# %%
class Teacher:
    def school(self,name,sub):
        self.name = name
        self.sub = sub
        print("Teacher Name:",self.name)
        print("Subject:",self.sub)

obj = Teacher()
obj.school("Neha","Maths")
# Out:
# Teacher Name: Neha
# Subject: Maths

# %% [markdown]
# # Q9. Create Multiple Objects
#
# ## Problem Statement
# Create a class named `Animal`.
#
# Create two different objects and print:
# - Animal Name
#
# ## Sample Output
# ```python
# Dog
# Cat
# ```

# %%
class Animal:
    name = "Dog"

    def janwar(self):
        print("Cat")

obj = Animal()
print(obj.name)
obj.janwar()
# Out:
# Dog
# Cat

# %% [markdown]
# # Q10. Simple Bank Class
#
# ## Problem Statement
# Create a class named `Bank`.
#
# Store:
# - Account Holder Name
# - Balance
#
# Print details using object.
#
# ## Sample Output
# ```python
# Name: Ritik
# Balance: 50000
# ```

# %%
class Bank:
    def details(self,name,balance):
        self.name = name
        self.balance = balance
        print("Name:",self.name)
        print("Balance:",self.balance)

obj = Bank()
obj.details("Ritik",50000)
# Out:
# Name: Ritik
# Balance: 50000
